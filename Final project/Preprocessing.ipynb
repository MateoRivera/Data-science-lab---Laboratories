# %% [markdown]
# ## Libraries

# %%
# For handling data
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# For plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# For Outlier Detection
from sklearn.ensemble import IsolationForest

# For Dimensionality Reduction
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# ## Reading the database ```development.csv```

# %%
path = './DSL_Winter_Project_2024/'
df = pd.read_csv(path + 'development.csv')

# %%
# Let's see what we have
df.head()
# Out:
#        x      y   pmax[0]  negpmax[0]   area[0]     tmax[0]    rms[0]  \
# 0  200.0  200.0  4.066907  -17.690173  2.847932    0.600000  2.007042
# 1  200.0  200.0  5.916801   -4.717111  5.792778   79.765174  1.564535
# 2  200.0  200.0  4.286652   -5.316132  2.356390   74.600000  1.404622
# 3  200.0  200.0  4.003635   -4.617459  2.189005   43.000000  1.512162
# 4  200.0  200.0  4.448146   -4.848743  3.997002  196.667482  1.101113
#
#     pmax[1]  negpmax[1]   area[1]  ...    pmax[16]  negpmax[16]    area[16]  \
# 0  5.409161  -17.721210  4.538778  ...  607.109118   -36.282996  583.899899
# 1  4.414289   -4.736827  3.720435  ...  630.348007   -39.715988  580.042799
# 2  4.567191   -5.985437  3.490490  ...  613.880342   -40.679678  580.407491
# 3  5.019058   -4.229949  6.786200  ...  600.714957   -43.206601  579.882635
# 4  3.250262   -5.783587  2.449456  ...  609.723785   -43.570892  590.156125
#
#     tmax[16]   rms[16]    pmax[17]  negpmax[17]    area[17]   tmax[17]  \
# 0  72.373094  0.374498  614.916861   -39.848523  591.852768  72.331028
# 1  71.029155  0.403258  624.950701   -41.266681  586.569646  71.089058
# 2  71.892264  0.568777  596.437125   -42.712286  574.091695  71.943934
# 3  72.357388  0.255483  591.763739   -50.681940  584.099483  72.333282
# 4  71.249130  0.413855  606.917023   -49.923819  584.316142  71.242904
#
#     rms[17]
# 0  0.405595
# 1  0.405890
# 2  0.498019
# 3  0.336454
# 4  0.293824
#
# [5 rows x 92 columns]

# %%
# Let's split the data into X and y (We have two variables to predict: x and y)
X = df.loc[:, 'pmax[0]':]
y1 = df['x']
y2 = df['y']

# %%
# Let's split X, y1 and y2 into train and test sets
X_train, X_test, y1_train, y1_test, y2_train, y2_test = train_test_split(X, y1, y2, test_size=0.3, random_state=0)

# Let's reset the indices
X_train.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)

y1_train.reset_index(drop=True, inplace=True)
y1_test.reset_index(drop=True, inplace=True)

y2_train.reset_index(drop=True, inplace=True)
y2_test.reset_index(drop=True, inplace=True)

# %%
# There is not na data
X_train.isna().sum().sum()
# Out:
# 0

# %%
X_train['pmax[0]'].hist()
# Out:
# <Axes: >

# %%
X_train['negpmax[0]'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Correlation data

# %%
correlation_matrix = X_train.corr()
correlation_matrix
# Out:
#               pmax[0]  negpmax[0]   area[0]   tmax[0]    rms[0]   pmax[1]  \
# pmax[0]      1.000000    0.025220  0.326791  0.011399  0.011369  0.039061
# negpmax[0]   0.025220    1.000000  0.034223  0.007014 -0.006160  0.000352
# area[0]      0.326791    0.034223  1.000000  0.022664 -0.004130  0.004314
# tmax[0]      0.011399    0.007014  0.022664  1.000000 -0.061725 -0.002889
# rms[0]       0.011369   -0.006160 -0.004130 -0.061725  1.000000 -0.001507
# ...               ...         ...       ...       ...       ...       ...
# pmax[17]     0.005724    0.000906  0.001377 -0.002618  0.011373  0.013361
# negpmax[17]  0.015272    0.005355  0.011008  0.012378 -0.020340  0.011779
# area[17]     0.016521    0.007341  0.002038  0.002610  0.003360  0.046078
# tmax[17]     0.048253    0.000168  0.011230  0.010810 -0.005771  0.006667
# rms[17]     -0.003998   -0.003696 -0.005892 -0.004488  0.004802 -0.004983
#
#              negpmax[1]   area[1]   tmax[1]    rms[1]  ...  pmax[16]  \
# pmax[0]        0.003213  0.036198  0.024983 -0.000750  ...  0.019361
# negpmax[0]     0.008121  0.001411  0.004702  0.004521  ... -0.001200
# area[0]        0.004754  0.005434  0.001119 -0.003655  ...  0.005586
# tmax[0]        0.001839 -0.004366  0.017980 -0.005055  ...  0.004560
# rms[0]        -0.001030 -0.001187 -0.000702  0.013783  ... -0.002539
# ...                 ...       ...       ...       ...  ...       ...
# pmax[17]      -0.003075  0.011035 -0.001545  0.008675  ... -0.040089
# negpmax[17]    0.000365  0.015090 -0.001251 -0.011999  ... -0.008652
# area[17]      -0.005218  0.047806 -0.010867  0.003945  ... -0.033969
# tmax[17]      -0.002275  0.007923  0.021141 -0.009039  ... -0.022465
# rms[17]       -0.001114 -0.007643  0.002292  0.003288  ... -0.013877
#
#              negpmax[16]  area[16]  tmax[16]   rms[16]  pmax[17]  negpmax[17]  \
# pmax[0]         0.016773  0.041410  0.042877  0.012654  0.005724     0.015272
# negpmax[0]     -0.013337  0.004160  0.001720  0.008998  0.000906     0.005355
# area[0]        -0.004767  0.005432  0.009526 -0.000988  0.001377     0.011008
# tmax[0]         0.001840  0.001066  0.004105 -0.011122 -0.002618     0.012378
# rms[0]          0.001456 -0.005963 -0.004402  0.026901  0.011373    -0.020340
# ...                  ...       ...       ...       ...       ...          ...
# pmax[17]        0.033041 -0.018158 -0.038456  0.102175  1.000000    -0.209484
# negpmax[17]     0.013383  0.101008  0.038763 -0.125064 -0.209484     1.000000
# area[17]        0.063484  0.128035 -0.011428 -0.008240  0.078457    -0.049829
# tmax[17]        0.019311  0.078339  0.983039 -0.017391 -0.051784     0.052719
# rms[17]        -0.000886 -0.037236  0.005647 -0.024990 -0.002933    -0.011154
#
#              area[17]  tmax[17]   rms[17]
# pmax[0]      0.016521  0.048253 -0.003998
# negpmax[0]   0.007341  0.000168 -0.003696
# area[0]      0.002038  0.011230 -0.005892
# tmax[0]      0.002610  0.010810 -0.004488
# rms[0]       0.003360 -0.005771  0.004802
# ...               ...       ...       ...
# pmax[17]     0.078457 -0.051784 -0.002933
# negpmax[17] -0.049829  0.052719 -0.011154
# area[17]     1.000000 -0.008443 -0.020885
# tmax[17]    -0.008443  1.000000 -0.002411
# rms[17]     -0.020885 -0.002411  1.000000
#
# [90 rows x 90 columns]

# %%
corr = correlation_matrix
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d50a1_row0_col0, #T_d50a1_row1_col1, #T_d50a1_row2_col2, #T_d50a1_row3_col3, #T_d50a1_row4_col4, #T_d50a1_row5_col5, #T_d50a1_row6_col6, #T_d50a1_row7_col7, #T_d50a1_row8_col8, #T_d50a1_row9_col9, #T_d50a1_row10_col10, #T_d50a1_row11_col11, #T_d50a1_row12_col12, #T_d50a1_row13_col13, #T_d50a1_row14_col14, #T_d50a1_row15_col15, #T_d50a1_row16_col16, #T_d50a1_row17_col17, #T_d50a1_row18_col18, #T_d50a1_row19_col19, #T_d50a1_row20_col20, #T_d50a1_row21_col21, #T_d50a1_row22_col22, #T_d50a1_row23_col23, #T_d50a1_row24_col24, #T_d50a1_row25_col25, #T_d50a1_row26_col26, #T_d50a1_row27_col27, #T_d50a1_row28_col28, #T_d50a1_row29_col29, #T_d50a1_row30_col30, #T_d50a1_row31_col31, #T_d50a1_row32_col32, #T_d50a1_row33_col33, #T_d50a1_row34_col34, #T_d50a1_row35_col35, #T_d50a1_row36_col36, #T_d50a1_row37_col37, #T_d50a1_row38_col38, #T_d50a1_row39_col39, #T_d50a1_row40_col40, #T_d50a1_row41_col41, #T_d50a1_row42_col42, #T_d50a1_row43_col43, #T_d50a1_row44_col44, #T_d50a1_row45_col45, #T_d50a1_row46_col46, #T_d50a1_row47_col47, #T_d50a1_row48_col48, #T_d50a1_row49_col49, #T_d50a1_row50_col50, #T_d50a1_row51_col51, #T_d50a1_row52_col52, #T_d50a1_row53_col53, #T_d50a1_row54_col54, #T_d50a1_row55_col55, #T_d50a1_row56_col56, #T_d50a1_row57_col57, #T_d50a1_row58_col58, #T_d50a1_row59_col59, #T_d50a1_row60_col60, #T_d50a1_row61_col61, #T_d50a1_row62_col62, #T_d50a1_row63_col63, #T_d50a1_row64_col64, #T_d50a1_row65_col65, #T_d50a1_row66_col66, #T_d50a1_row67_col67, #T_d50a1_row68_col68, #T_d50a1_row69_col69, #T_d50a1_row70_col70, #T_d50a1_row71_col71, #T_d50a1_row72_col72, #T_d50a1_row73_col73, #T_d50a1_row74_col74, #T_d50a1_row75_col75, #T_d50a1_row76_col76, #T_d50a1_row77_col77, #T_d50a1_row78_col78, #T_d50a1_row79_col79, #T_d50a1_row80_col80, #T_d50a1_row81_col81, #T_d50a1_row82_col82, #T_d50a1_row83_col83, #T_d50a1_row84_col84, #T_d50a1_row85_col85, #T_d50a1_row86_col86, #T_d50a1_row87_col87, #T_d50a1_row88_col88, #T_d50a1_row89_col89 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d50a1_row0_col1, #T_d50a1_row1_col0, #T_d50a1_row3_col77, #T_d50a1_row4_col34, #T_d50a1_row4_col77, #T_d50a1_row5_col8, #T_d50a1_row5_col45, #T_d50a1_row5_col52, #T_d50a1_row7_col8, #T_d50a1_row8_col0, #T_d50a1_row8_col35, #T_d50a1_row8_col74, #T_d50a1_row8_col87, #T_d50a1_row8_col89, #T_d50a1_row9_col34, #T_d50a1_row9_col77, #T_d50a1_row9_col83, #T_d50a1_row10_col13, #T_d50a1_row10_col16, #T_d50a1_row11_col77, #T_d50a1_row11_col89, #T_d50a1_row13_col82, #T_d50a1_row14_col9, #T_d50a1_row14_col77, #T_d50a1_row14_col89, #T_d50a1_row15_col0, #T_d50a1_row15_col68, #T_d50a1_row16_col14, #T_d50a1_row17_col28, #T_d50a1_row17_col68, #T_d50a1_row19_col9, #T_d50a1_row19_col24, #T_d50a1_row19_col77, #T_d50a1_row19_col89, #T_d50a1_row21_col89, #T_d50a1_row22_col57, #T_d50a1_row23_col14, #T_d50a1_row23_col49, #T_d50a1_row24_col9, #T_d50a1_row24_col82, #T_d50a1_row25_col35, #T_d50a1_row25_col53, #T_d50a1_row26_col68, #T_d50a1_row26_col71, #T_d50a1_row26_col89, #T_d50a1_row27_col0, #T_d50a1_row27_col53, #T_d50a1_row28_col14, #T_d50a1_row29_col34, #T_d50a1_row29_col77, #T_d50a1_row29_col83, #T_d50a1_row30_col41, #T_d50a1_row30_col89, #T_d50a1_row31_col74, #T_d50a1_row32_col41, #T_d50a1_row33_col0, #T_d50a1_row33_col89, #T_d50a1_row34_col9, #T_d50a1_row36_col1, #T_d50a1_row36_col77, #T_d50a1_row37_col14, #T_d50a1_row38_col14, #T_d50a1_row39_col9, #T_d50a1_row39_col34, #T_d50a1_row39_col77, #T_d50a1_row39_col83, #T_d50a1_row40_col48, #T_d50a1_row40_col74, #T_d50a1_row40_col89, #T_d50a1_row41_col14, #T_d50a1_row41_col89, #T_d50a1_row42_col48, #T_d50a1_row42_col74, #T_d50a1_row42_col89, #T_d50a1_row43_col49, #T_d50a1_row44_col77, #T_d50a1_row45_col53, #T_d50a1_row46_col77, #T_d50a1_row47_col49, #T_d50a1_row47_col53, #T_d50a1_row47_col89, #T_d50a1_row48_col14, #T_d50a1_row49_col59, #T_d50a1_row49_col82, #T_d50a1_row50_col41, #T_d50a1_row50_col89, #T_d50a1_row51_col89, #T_d50a1_row52_col41, #T_d50a1_row52_col87, #T_d50a1_row52_col89, #T_d50a1_row54_col77, #T_d50a1_row55_col60, #T_d50a1_row57_col49, #T_d50a1_row58_col49, #T_d50a1_row58_col60, #T_d50a1_row60_col14, #T_d50a1_row60_col74, #T_d50a1_row61_col89, #T_d50a1_row62_col0, #T_d50a1_row62_col14, #T_d50a1_row62_col35, #T_d50a1_row62_col89, #T_d50a1_row63_col77, #T_d50a1_row64_col59, #T_d50a1_row65_col71, #T_d50a1_row66_col41, #T_d50a1_row66_col89, #T_d50a1_row67_col71, #T_d50a1_row68_col49, #T_d50a1_row68_col87, #T_d50a1_row69_col44, #T_d50a1_row69_col59, #T_d50a1_row69_col77, #T_d50a1_row70_col58, #T_d50a1_row70_col89, #T_d50a1_row71_col89, #T_d50a1_row72_col58, #T_d50a1_row73_col82, #T_d50a1_row74_col77, #T_d50a1_row75_col89, #T_d50a1_row76_col49, #T_d50a1_row78_col14, #T_d50a1_row79_col59, #T_d50a1_row79_col77, #T_d50a1_row80_col14, #T_d50a1_row80_col35, #T_d50a1_row80_col49, #T_d50a1_row82_col14, #T_d50a1_row83_col14, #T_d50a1_row83_col87, #T_d50a1_row84_col74, #T_d50a1_row85_col29, #T_d50a1_row85_col44, #T_d50a1_row85_col74, #T_d50a1_row86_col4, #T_d50a1_row88_col14, #T_d50a1_row89_col68 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_d50a1_row0_col2, #T_d50a1_row1_col57, #T_d50a1_row2_col55, #T_d50a1_row9_col57, #T_d50a1_row11_col57, #T_d50a1_row14_col57, #T_d50a1_row14_col70, #T_d50a1_row16_col45, #T_d50a1_row19_col57, #T_d50a1_row19_col70, #T_d50a1_row21_col5, #T_d50a1_row23_col47, #T_d50a1_row24_col57, #T_d50a1_row28_col22, #T_d50a1_row31_col10, #T_d50a1_row33_col75, #T_d50a1_row34_col57, #T_d50a1_row34_col70, #T_d50a1_row37_col57, #T_d50a1_row39_col57, #T_d50a1_row39_col70, #T_d50a1_row40_col20, #T_d50a1_row41_col5, #T_d50a1_row41_col72, #T_d50a1_row42_col22, #T_d50a1_row44_col57, #T_d50a1_row53_col12, #T_d50a1_row54_col57, #T_d50a1_row56_col7, #T_d50a1_row56_col52, #T_d50a1_row59_col57, #T_d50a1_row60_col5, #T_d50a1_row61_col57, #T_d50a1_row62_col72, #T_d50a1_row63_col55, #T_d50a1_row64_col57, #T_d50a1_row72_col33, #T_d50a1_row78_col5, #T_d50a1_row80_col42, #T_d50a1_row81_col30, #T_d50a1_row81_col42, #T_d50a1_row82_col10, #T_d50a1_row82_col30, #T_d50a1_row82_col50, #T_d50a1_row83_col57, #T_d50a1_row84_col70, #T_d50a1_row85_col32, #T_d50a1_row86_col5, #T_d50a1_row86_col40, #T_d50a1_row86_col57, #T_d50a1_row88_col5, #T_d50a1_row88_col57 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_d50a1_row0_col3, #T_d50a1_row0_col4, #T_d50a1_row0_col53, #T_d50a1_row2_col28, #T_d50a1_row2_col63, #T_d50a1_row2_col64, #T_d50a1_row3_col53, #T_d50a1_row4_col64, #T_d50a1_row5_col28, #T_d50a1_row5_col63, #T_d50a1_row5_col64, #T_d50a1_row7_col28, #T_d50a1_row7_col63, #T_d50a1_row7_col64, #T_d50a1_row8_col88, #T_d50a1_row10_col28, #T_d50a1_row10_col63, #T_d50a1_row10_col64, #T_d50a1_row11_col63, #T_d50a1_row12_col63, #T_d50a1_row12_col64, #T_d50a1_row14_col39, #T_d50a1_row14_col53, #T_d50a1_row14_col64, #T_d50a1_row15_col41, #T_d50a1_row15_col55, #T_d50a1_row15_col57, #T_d50a1_row15_col63, #T_d50a1_row15_col64, #T_d50a1_row15_col87, #T_d50a1_row16_col64, #T_d50a1_row17_col41, #T_d50a1_row17_col63, #T_d50a1_row17_col64, #T_d50a1_row19_col4, #T_d50a1_row19_col39, #T_d50a1_row19_col63, #T_d50a1_row20_col13, #T_d50a1_row20_col35, #T_d50a1_row20_col43, #T_d50a1_row20_col47, #T_d50a1_row20_col63, #T_d50a1_row20_col64, #T_d50a1_row21_col63, #T_d50a1_row21_col64, #T_d50a1_row22_col43, #T_d50a1_row22_col63, #T_d50a1_row22_col64, #T_d50a1_row22_col71, #T_d50a1_row23_col3, #T_d50a1_row24_col4, #T_d50a1_row24_col63, #T_d50a1_row24_col64, #T_d50a1_row25_col64, #T_d50a1_row26_col63, #T_d50a1_row26_col73, #T_d50a1_row27_col64, #T_d50a1_row28_col64, #T_d50a1_row29_col4, #T_d50a1_row29_col63, #T_d50a1_row29_col64, #T_d50a1_row30_col57, #T_d50a1_row30_col63, #T_d50a1_row30_col64, #T_d50a1_row30_col65, #T_d50a1_row30_col71, #T_d50a1_row31_col63, #T_d50a1_row32_col63, #T_d50a1_row32_col64, #T_d50a1_row32_col71, #T_d50a1_row34_col4, #T_d50a1_row34_col63, #T_d50a1_row35_col38, #T_d50a1_row35_col39, #T_d50a1_row35_col53, #T_d50a1_row36_col64, #T_d50a1_row37_col28, #T_d50a1_row38_col53, #T_d50a1_row38_col64, #T_d50a1_row39_col63, #T_d50a1_row39_

# %%
mask_gt = correlation_matrix >= 0.8 
mask_lt = correlation_matrix <= -0.8

# %%
features_correlated = []
for i, row in enumerate(correlation_matrix.index):
    for j, column in enumerate(correlation_matrix.columns):
        if mask_gt.loc[row, column] or mask_lt.loc[row, column]:
            if  i < j:
                features_correlated.append((row, column))
features_correlated
# Out:
# [('pmax[1]', 'area[1]'),
#  ('pmax[3]', 'area[3]'),
#  ('pmax[4]', 'area[4]'),
#  ('pmax[5]', 'negpmax[5]'),
#  ('pmax[5]', 'area[5]'),
#  ('negpmax[5]', 'area[5]'),
#  ('pmax[6]', 'area[6]'),
#  ('pmax[8]', 'area[8]'),
#  ('pmax[9]', 'area[9]'),
#  ('pmax[10]', 'area[10]'),
#  ('pmax[11]', 'area[11]'),
#  ('pmax[13]', 'area[13]'),
#  ('pmax[14]', 'area[14]'),
#  ('tmax[15]', 'tmax[16]'),
#  ('tmax[15]', 'tmax[17]'),
#  ('tmax[16]', 'tmax[17]')]

# %% [markdown]
# We will handle highly correlated features later with PCA

# %% [markdown]
# ## Outliers
# We have a multivariate problem, so We will detect outliers using Isolation Forest.
# We considered the following documentation, for choosing the outlier detector: https://scikit-learn.org/stable/modules/outlier_detection.html#overview-of-outlier-detection-methods

# %%
isolation_forest = IsolationForest(n_estimators=1000)
X_train['is_outlier'] = isolation_forest.fit_predict(X_train) # fit_predict returns -1 for outliers and 1 for inliers

# %%
X_train['is_outlier'].value_counts() 
# 2029 n_estimators=100
# 2809 n_estimators=1000
# 2544 n_estimators=10000
# Out:
# is_outlier
#  1    266907
# -1      2943
# Name: count, dtype: int64

# %%
mask_is_outlier = X_train['is_outlier'] == -1
plt.scatter(y1_train[~mask_is_outlier], y2_train[~mask_is_outlier], c='orange', label='inliers')
plt.scatter(y1_train[mask_is_outlier], y2_train[mask_is_outlier], c='red', label='outliers', alpha=0.3)

plt.show()

# %%
X_train_without_outliers, y1_train_without_outliers, y2_train_without_outliers = X_train[~mask_is_outlier], y1_train[~mask_is_outlier], y2_train[~mask_is_outlier]
del(X_train_without_outliers['is_outlier'])
del(X_train['is_outlier'])

# %%
# Let's reset the index
X_train_without_outliers.reset_index(drop=True, inplace=True)
y1_train_without_outliers.reset_index(drop=True, inplace=True)
y2_train_without_outliers.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Normalization

# %%
scaler_without_outliers = StandardScaler()
scaler = StandardScaler()

X_train_without_outliers_scaled = scaler_without_outliers.fit_transform(X_train_without_outliers)
X_train_scaled = scaler.fit_transform(X_train)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_train_without_outliers_scaled = pd.DataFrame(X_train_without_outliers_scaled, columns=X_train.columns)
X_train_scaled.head()
# Out:
#     pmax[0]  negpmax[0]   area[0]   tmax[0]    rms[0]   pmax[1]  negpmax[1]  \
# 0 -1.044612   -0.019463 -0.550867 -1.635290  0.800553 -0.403626    0.110149
# 1 -0.100777    0.039032 -0.556090  1.554349 -1.355075 -0.135414    0.142123
# 2 -0.556785   -0.004540 -0.540431  0.551699  0.378050 -0.717708    0.141147
# 3  6.445931   -0.024792  0.264341 -0.272628  0.021652 -0.149203    0.098734
# 4 -0.481804   -0.107773 -0.154613  1.328921  0.132850 -0.559152    0.100097
#
#     area[1]   tmax[1]    rms[1]  ...  pmax[16]  negpmax[16]  area[16]  \
# 0 -0.433077 -0.196916 -1.042132  ... -0.448756     0.867958  1.589746
# 1 -0.044530 -0.190260  1.524673  ... -0.821098     0.781175 -1.045967
# 2 -0.992513 -1.461449  1.217592  ...  1.159502     1.432768  0.421983
# 3 -0.170069  0.135856  0.743030  ...  1.300639    -0.915322 -0.575901
# 4 -0.806156 -0.196916 -0.459130  ... -0.280953    -1.317720 -0.359143
#
#    tmax[16]   rms[16]  pmax[17]  negpmax[17]  area[17]  tmax[17]   rms[17]
# 0 -0.511599 -0.656170  0.378069     1.040924 -0.628667 -0.655573  0.851835
# 1  0.097811 -0.287338  0.248847    -1.267613  0.019443  0.262788 -0.939558
# 2 -1.196525 -0.034111 -0.197379    -1.270574  0.857758 -1.222677 -1.499744
# 3  0.033980 -0.381418 -1.163485     0.633640  2.322367 -0.223300 -0.222790
# 4 -0.647641 -0.351670 -0.607459    -0.587627  0.721373 -0.502974 -1.083888
#
# [5 rows x 90 columns]

# %% [markdown]
# # PCA

# %%
pca = PCA()
pca_without_outliers = PCA()

pca.fit(X_train_scaled)
pca_without_outliers.fit(X_train_without_outliers_scaled)

plt.figure(figsize=(20,8))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.plot(np.cumsum(pca_without_outliers.explained_variance_ratio_))
# plt.xticks(ticks=np.arange(pca.n_features_), 
#             labels=[f'PC{i + 1}' for i in range(pca.n_features_)])


# plt.figure(figsize=(20,8))
# plt.plot(np.cumsum(pca.explained_variance_ratio_))
# plt.title('Xworkdf')
# #plt.ylim([0, 1.1])
# plt.xticks(ticks=np.arange(pca.n_features_), 
#            labels=[f'PC{i + 1}' for i in range(pca.n_features_)])
# plt.xlabel('Principal components')
# plt.ylabel('Cumulative explained variance')
# plt.grid()
# plt.show()

# %%
print(np.cumsum(pca.explained_variance_ratio_))
print(np.cumsum(pca_without_outliers.explained_variance_ratio_))
# Out:
# [0.09265431 0.17189915 0.20840624 0.24277017 0.2701079  0.29147687
#  0.3092045  0.32536225 0.34117631 0.35649147 0.37024946 0.38317385
#  0.39580491 0.40830884 0.42069668 0.4328985  0.44492961 0.45683976
#  0.46850847 0.48003572 0.49155268 0.50293178 0.51427085 0.52551907
#  0.53672811 0.54790585 0.5590589  0.57019881 0.58132065 0.59241924
#  0.60350962 0.61456927 0.62561931 0.63665448 0.64766916 0.65867167
#  0.66965836 0.68061588 0.69155481 0.70244595 0.71330107 0.72406319
#  0.73478183 0.74538089 0.75589097 0.76629629 0.7766554  0.78698371
#  0.7972071  0.80739681 0.81748269 0.82752806 0.83749376 0.84740841
#  0.85724503 0.86700581 0.87673854 0.88630605 0.89578127 0.90518669
#  0.91444404 0.92346204 0.93225638 0.94079499 0.94894872 0.95675644
#  0.96336263 0.96959502 0.97542439 0.98011166 0.98459657 0.98807887
#  0.9908995  0.99244697 0.99385347 0.99501665 0.99577816 0.99639204
#  0.99697366 0.99746321 0.99792591 0.99827968 0.99858783 0.99886432
#  0.99911558 0.99936265 0.99958155 0.99977892 0.99997332 1.        ]
# [0.0926927  0.17199595 0.20842347 0.24285398 0.27012096 0.29143724
#  0.30912545 0.32526062 0.34102226 0.35632704 0.36927243 0.38196178
#  0.39449187 0.40690631 0.41911424 0.43124925 0.44322328 0.45502672
#  0.46669937 0.47823948 0.48964193 0.50095815 0.51225324 0.52351898
#  0.53476217 0.5459615  0.55713634 0.56829975 0.5794352  0.59054606
#  0.60164302 0.61272928 0.62381377 0.63488976 0.64593721 0.6569605
#  0.66797373 0.67897778 0.68995167 0.70088189 0.71176932 0.72260505
#  0.7333632  0.74400834 0.75462003 0.76515057 0.77556951 0.78592367
#  0.79623747 0.80647625 0.816658   0.82676182 0.83683982 0.84679142
#  0.85671239 0.8665751  0.8763485  0.88598166 0.89556209 0.90505993
#  0.91438065 0.92339229 0.93224899 0.94079576 0.94890499 0.95671355
#  0.96332204 0.9695525  0.97538324 0.98008813 0.98457549 0.98805988
#  0.99090449 0.99245584 0.993864   0.99503078 0.99579516 0.99641221
#  0.99699681 0.99748827 0.99793019 0.99828512 0.99859287 0.99886976
#  0.99912154 0.99936869 0.99958773 0.99978302 0.99997335 1.        ]

# %%
def findm(pca):
        for i,var in enumerate(np.cumsum(pca.explained_variance_ratio_)):
                if var>=0.9:        
                        m=i+1 #It is +1 because the counting starts from 0
                        break    
        return m

# %%
n = findm(pca)
n_without_outliers = findm(pca_without_outliers)
n
print(f"n = {n} and n_without_outliers = {n_without_outliers}")
# Out:
# n = 60 and n_without_outliers = 60

# %%
pca = PCA(n_components=n)
pca_without_outliers = PCA(n_components=n_without_outliers)

pca.fit(X_train_scaled)
pca_without_outliers.fit(X_train_without_outliers_scaled)
# Out:
# PCA(n_components=60)

# %%
X_train_pca = pca.transform(X_train_scaled)
X_train_without_outliers_pca = pca_without_outliers.transform(X_train_without_outliers_scaled)

# %%
X_train_pca = pd.DataFrame(X_train_pca, columns=[f'PC{i + 1}' for i in range(n)])
X_train_without_outliers_pca = pd.DataFrame(X_train_without_outliers_pca, columns=[f'PC{i + 1}' for i in range(n_without_outliers)])

# %%
# Download the datasets with outliers and without outliers respectively
pd.concat([X_train, y1_train, y2_train], axis=1).to_csv(path + 'train.csv', index=False)
pd.concat([X_train_without_outliers, y1_train_without_outliers, y2_train_without_outliers], axis=1).to_csv(path + 'train_without_outliers.csv', index=False)

# Download the datasets scaled with outliers and without outliers respectively
pd.concat([X_train_scaled, y1_train, y2_train], axis=1).to_csv(path + 'train_scaled.csv', index=False)
pd.concat([X_train_without_outliers_scaled, y1_train_without_outliers, y2_train_without_outliers], axis=1).to_csv(path + 'train_without_outliers_scaled.csv', index=False)

# Download the datasets scaled and pca with outliers and without outliers respectively
pd.concat([X_train_pca, y1_train, y2_train], axis=1).to_csv(path + 'train_pca.csv', index=False)
pd.concat([X_train_without_outliers_pca, y1_train_without_outliers, y2_train_without_outliers], axis=1).to_csv(path + 'train_without_outliers_pca.csv', index=False)

# %%
# Download the test set
pd.concat([X_test, y1_test, y2_test], axis=1).to_csv(path + 'test.csv', index=False)

# %%
X_test = pd.read_csv(path + 'evaluation.csv', index_col=0)

# %%
X_test.head()
# Out:
#      pmax[0]  negpmax[0]   area[0]     tmax[0]    rms[0]    pmax[1]  \
# Id
# 0   4.400616   -4.257770  2.860212  176.600000  1.562814   8.738040
# 1   5.599571   -2.974570  9.400537   90.677386  1.129626  23.460358
# 2   3.731995   -5.662292  1.930957  155.200000  0.921757   4.837952
# 3   5.657729   -4.600342  5.593030   30.463179  1.269390  87.293692
# 4   3.716666   -4.583796  1.946927   33.600000  1.082743   9.593125
#
#     negpmax[1]    area[1]    tmax[1]    rms[1]  ...    pmax[16]  negpmax[16]  \
# Id                                              ...
# 0    -3.598874   5.554105  70.800000  0.729175  ...  614.621212   -42.232574
# 1   -20.616669  17.998419  72.800000  1.258335  ...  520.333440   -36.986118
# 2    -7.224267   3.289124  67.057395  0.793541  ...  607.642389   -46.680069
# 3   -45.786813  38.422989  71.800000  0.733773  ...  596.094911   -48.241263
# 4    -5.374179   7.767408  72.414459  1.572473  ...  620.793628   -37.618567
#
#       area[16]   tmax[16]   rms[16]    pmax[17]  negpmax[17]    area[17]  \
# Id
# 0   583.237137  70.693530  0.861022  608.931417   -42.728827  568.019556
# 1   550.540448  72.781390  0.259205  613.671695   -44.449564  586.292097
# 2   582.825835  71.407320  0.552691  608.996069   -45.877765  589.520958
# 3   577.835129  72.011986  0.361220  612.500144   -49.572583  583.795426
# 4   599.834735  72.251813  0.390639  621.557649   -45.189832  600.988676
#
#      tmax[17]   rms[17]
# Id
# 0   70.755552  0.328075
# 1   72.900695  0.401326
# 2   71.406020  0.343592
# 3   72.066338  0.429650
# 4   72.151243  0.358549
#
# [5 rows x 90 columns]

# %%
X_test_scaled = scaler_without_outliers.transform(X_test)

# %%
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
X_test_scaled.head()
# Out:
#     pmax[0]  negpmax[0]   area[0]   tmax[0]    rms[0]   pmax[1]  negpmax[1]  \
# 0 -0.316981    0.056264 -0.421964  1.328585  0.653763 -0.463227    0.156061
# 1  0.496200    0.171941  1.450000 -0.117820 -0.615578  0.417136   -0.325734
# 2 -0.770468   -0.070350 -0.687934  0.968341 -1.224685 -0.696444    0.053422
# 3  0.535645    0.025382  0.360220 -1.131454 -0.206038  4.234232   -1.038332
# 4 -0.780865    0.026874 -0.683364 -1.078649 -0.752956 -0.412095    0.105800
#
#     area[1]   tmax[1]    rms[1]  ...  pmax[16]  negpmax[16]  area[16]  \
# 0 -0.586443 -0.217996 -1.787555  ...  0.436988    -0.021441 -0.051351
# 1  0.892202 -0.151186 -0.230149  ... -6.462255     1.640903 -4.963990
# 2 -0.855570 -0.343018 -1.598116  ... -0.073668    -1.430633 -0.113149
# 3  3.319069 -0.184591 -1.774024  ... -0.918622    -1.925299 -0.862996
# 4 -0.323456 -0.164065  0.694414  ...  0.888637     1.440511  2.442419
#
#    tmax[16]   rms[16]  pmax[17]  negpmax[17]  area[17]  tmax[17]   rms[17]
# 0 -1.621942  1.357839 -0.009068     1.202340 -2.151953 -1.607909 -0.575607
# 1  1.996306 -0.649619  0.332367     0.708288  0.459477  2.059479  0.411750
# 2 -0.384950  0.329353 -0.004411     0.298228  0.920931 -0.495853 -0.366457
# 3  0.662935 -0.309329  0.247982    -0.762615  0.102664  0.633041  0.793543
# 4  1.078553 -0.211197  0.900382     0.495745  2.559846  0.778197 -0.164846
#
# [5 rows x 90 columns]

# %%
X_test_pca = pca_without_outliers.transform(X_test_scaled)
X_test_pca = pd.DataFrame(X_test_pca, columns=[f'PC{i + 1}' for i in range(n_without_outliers)])

# %%
X_test_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  1.629172 -0.747091  1.751286 -2.387680  1.348266  0.134697 -2.822340
# 1  1.520814  3.073045 -3.368477  2.864238 -0.282897 -0.407310 -0.123575
# 2 -3.725690 -2.205500 -1.501696 -0.857698 -0.697578  1.353251  1.889767
# 3  3.687312  3.707440 -3.585558  0.552387 -0.564559 -0.129646  0.919350
# 4 -0.212521 -1.554334  0.312922  1.869607  1.957009 -0.142746  0.652769
#
#         PC8       PC9      PC10  ...      PC51      PC52      PC53      PC54  \
# 0 -3.130940 -0.092565  0.946599  ... -0.238087 -1.003990 -0.896669  1.934056
# 1  1.976719 -1.536066  2.530527  ... -0.050556  0.706704  0.672575  0.662658
# 2 -1.715980 -0.914584 -1.097777  ...  0.739583  1.419481  0.896278  0.547216
# 3 -0.510986 -0.479698 -0.380220  ... -0.132125 -1.013128  1.194652  0.087187
# 4  0.995226  0.436601 -0.564031  ... -0.010478 -0.132637  0.610855 -0.614012
#
#        PC55      PC56      PC57      PC58      PC59      PC60
# 0 -1.276082  0.351101 -1.272192 -0.410019  1.632607  1.061555
# 1 -2.324821 -1.365160  3.639817  0.257041 -1.877967 -2.187070
# 2 -0.321641 -0.974794  1.228556 -1.488651  0.593174 -0.894921
# 3  0.207318  0.330908  1.089944 -1.440991  0.734865 -1.267708
# 4  0.435866  0.594309 -0.715705 -0.110151  0.086527  0.291779
#
# [5 rows x 60 columns]

# %%
X_test_pca.to_csv(path + 'evaluation_pca.csv', index=True)
