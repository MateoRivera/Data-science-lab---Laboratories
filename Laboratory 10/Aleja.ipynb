# %%
# !pip install nltk
# Out:
# ...
#      ---------------------------------------- 1.5/1.5 MB 16.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 269.5/269.5 kB ? eta 0:00:00
# ...

# %%
import nltk
import numpy as np
from sklearn import metrics
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
import scipy 
import pandas as pd
import matplotlib.pyplot as py

# %%
data=pd.read_csv('https://raw.githubusercontent.com/dbdmg/data-science-lab/master/datasets/2D_gauss_clusters.txt', sep=',')

# %%
py.scatter(data['x'],data['y']) #The best option would be a center based clusterization due to the small dense between big denses

# %%
class KMeans:
    def __init__(self, n_clusters, max_iter=100):
        self.n_clusters = n_clusters
        self.max_iter = max_iter
        self.centroids = None
        self.labels = None
    def fit_predict(self, X):
        self.centroids=np.random.sample(X, self.n_clusters)

        """Run the K-means clustering on X.
        :param X: input data points, array, shape = (N,C).
        :return: labels : array, shape = N.
        """
    pass
