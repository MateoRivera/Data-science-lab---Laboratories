# %% [markdown]
# ## Libraries

# %%
# For handling data
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# For plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# For Outlier Detection
from sklearn.ensemble import IsolationForest

# For Dimensionality Reduction
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# ## Reading the database ```development.csv```

# %%
path = './DSL_Winter_Project_2024/'
df = pd.read_csv(path + 'development.csv')

# %%
# Let's see what we have
df.head()
# Out:
#        x      y   pmax[0]  negpmax[0]   area[0]     tmax[0]    rms[0]  \
# 0  200.0  200.0  4.066907  -17.690173  2.847932    0.600000  2.007042
# 1  200.0  200.0  5.916801   -4.717111  5.792778   79.765174  1.564535
# 2  200.0  200.0  4.286652   -5.316132  2.356390   74.600000  1.404622
# 3  200.0  200.0  4.003635   -4.617459  2.189005   43.000000  1.512162
# 4  200.0  200.0  4.448146   -4.848743  3.997002  196.667482  1.101113
#
#     pmax[1]  negpmax[1]   area[1]  ...    pmax[16]  negpmax[16]    area[16]  \
# 0  5.409161  -17.721210  4.538778  ...  607.109118   -36.282996  583.899899
# 1  4.414289   -4.736827  3.720435  ...  630.348007   -39.715988  580.042799
# 2  4.567191   -5.985437  3.490490  ...  613.880342   -40.679678  580.407491
# 3  5.019058   -4.229949  6.786200  ...  600.714957   -43.206601  579.882635
# 4  3.250262   -5.783587  2.449456  ...  609.723785   -43.570892  590.156125
#
#     tmax[16]   rms[16]    pmax[17]  negpmax[17]    area[17]   tmax[17]  \
# 0  72.373094  0.374498  614.916861   -39.848523  591.852768  72.331028
# 1  71.029155  0.403258  624.950701   -41.266681  586.569646  71.089058
# 2  71.892264  0.568777  596.437125   -42.712286  574.091695  71.943934
# 3  72.357388  0.255483  591.763739   -50.681940  584.099483  72.333282
# 4  71.249130  0.413855  606.917023   -49.923819  584.316142  71.242904
#
#     rms[17]
# 0  0.405595
# 1  0.405890
# 2  0.498019
# 3  0.336454
# 4  0.293824
#
# [5 rows x 92 columns]

# %%
# Let's split the data into X and y (We have two variables to predict: x and y)
X = df.loc[:, 'pmax[0]':]
y = df[['x', 'y']]

# %%
# Let's split X, y1 and y2 into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Let's reset the indices
X_train.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)

y_train.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)

# %%
# There is not na data
X_train.isna().sum().sum()
# Out:
# 0

# %%
X_train['pmax[0]'].hist()
# Out:
# <Axes: >

# %%
X_train['negpmax[0]'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ## Correlation data

# %%
correlation_matrix = X_train.corr()
correlation_matrix
# Out:
#               pmax[0]  negpmax[0]   area[0]   tmax[0]    rms[0]   pmax[1]  \
# pmax[0]      1.000000    0.025220  0.326791  0.011399  0.011369  0.039061
# negpmax[0]   0.025220    1.000000  0.034223  0.007014 -0.006160  0.000352
# area[0]      0.326791    0.034223  1.000000  0.022664 -0.004130  0.004314
# tmax[0]      0.011399    0.007014  0.022664  1.000000 -0.061725 -0.002889
# rms[0]       0.011369   -0.006160 -0.004130 -0.061725  1.000000 -0.001507
# ...               ...         ...       ...       ...       ...       ...
# pmax[17]     0.005724    0.000906  0.001377 -0.002618  0.011373  0.013361
# negpmax[17]  0.015272    0.005355  0.011008  0.012378 -0.020340  0.011779
# area[17]     0.016521    0.007341  0.002038  0.002610  0.003360  0.046078
# tmax[17]     0.048253    0.000168  0.011230  0.010810 -0.005771  0.006667
# rms[17]     -0.003998   -0.003696 -0.005892 -0.004488  0.004802 -0.004983
#
#              negpmax[1]   area[1]   tmax[1]    rms[1]  ...  pmax[16]  \
# pmax[0]        0.003213  0.036198  0.024983 -0.000750  ...  0.019361
# negpmax[0]     0.008121  0.001411  0.004702  0.004521  ... -0.001200
# area[0]        0.004754  0.005434  0.001119 -0.003655  ...  0.005586
# tmax[0]        0.001839 -0.004366  0.017980 -0.005055  ...  0.004560
# rms[0]        -0.001030 -0.001187 -0.000702  0.013783  ... -0.002539
# ...                 ...       ...       ...       ...  ...       ...
# pmax[17]      -0.003075  0.011035 -0.001545  0.008675  ... -0.040089
# negpmax[17]    0.000365  0.015090 -0.001251 -0.011999  ... -0.008652
# area[17]      -0.005218  0.047806 -0.010867  0.003945  ... -0.033969
# tmax[17]      -0.002275  0.007923  0.021141 -0.009039  ... -0.022465
# rms[17]       -0.001114 -0.007643  0.002292  0.003288  ... -0.013877
#
#              negpmax[16]  area[16]  tmax[16]   rms[16]  pmax[17]  negpmax[17]  \
# pmax[0]         0.016773  0.041410  0.042877  0.012654  0.005724     0.015272
# negpmax[0]     -0.013337  0.004160  0.001720  0.008998  0.000906     0.005355
# area[0]        -0.004767  0.005432  0.009526 -0.000988  0.001377     0.011008
# tmax[0]         0.001840  0.001066  0.004105 -0.011122 -0.002618     0.012378
# rms[0]          0.001456 -0.005963 -0.004402  0.026901  0.011373    -0.020340
# ...                  ...       ...       ...       ...       ...          ...
# pmax[17]        0.033041 -0.018158 -0.038456  0.102175  1.000000    -0.209484
# negpmax[17]     0.013383  0.101008  0.038763 -0.125064 -0.209484     1.000000
# area[17]        0.063484  0.128035 -0.011428 -0.008240  0.078457    -0.049829
# tmax[17]        0.019311  0.078339  0.983039 -0.017391 -0.051784     0.052719
# rms[17]        -0.000886 -0.037236  0.005647 -0.024990 -0.002933    -0.011154
#
#              area[17]  tmax[17]   rms[17]
# pmax[0]      0.016521  0.048253 -0.003998
# negpmax[0]   0.007341  0.000168 -0.003696
# area[0]      0.002038  0.011230 -0.005892
# tmax[0]      0.002610  0.010810 -0.004488
# rms[0]       0.003360 -0.005771  0.004802
# ...               ...       ...       ...
# pmax[17]     0.078457 -0.051784 -0.002933
# negpmax[17] -0.049829  0.052719 -0.011154
# area[17]     1.000000 -0.008443 -0.020885
# tmax[17]    -0.008443  1.000000 -0.002411
# rms[17]     -0.020885 -0.002411  1.000000
#
# [90 rows x 90 columns]

# %%
corr = correlation_matrix
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_cdb6a_row0_col0, #T_cdb6a_row1_col1, #T_cdb6a_row2_col2, #T_cdb6a_row3_col3, #T_cdb6a_row4_col4, #T_cdb6a_row5_col5, #T_cdb6a_row6_col6, #T_cdb6a_row7_col7, #T_cdb6a_row8_col8, #T_cdb6a_row9_col9, #T_cdb6a_row10_col10, #T_cdb6a_row11_col11, #T_cdb6a_row12_col12, #T_cdb6a_row13_col13, #T_cdb6a_row14_col14, #T_cdb6a_row15_col15, #T_cdb6a_row16_col16, #T_cdb6a_row17_col17, #T_cdb6a_row18_col18, #T_cdb6a_row19_col19, #T_cdb6a_row20_col20, #T_cdb6a_row21_col21, #T_cdb6a_row22_col22, #T_cdb6a_row23_col23, #T_cdb6a_row24_col24, #T_cdb6a_row25_col25, #T_cdb6a_row26_col26, #T_cdb6a_row27_col27, #T_cdb6a_row28_col28, #T_cdb6a_row29_col29, #T_cdb6a_row30_col30, #T_cdb6a_row31_col31, #T_cdb6a_row32_col32, #T_cdb6a_row33_col33, #T_cdb6a_row34_col34, #T_cdb6a_row35_col35, #T_cdb6a_row36_col36, #T_cdb6a_row37_col37, #T_cdb6a_row38_col38, #T_cdb6a_row39_col39, #T_cdb6a_row40_col40, #T_cdb6a_row41_col41, #T_cdb6a_row42_col42, #T_cdb6a_row43_col43, #T_cdb6a_row44_col44, #T_cdb6a_row45_col45, #T_cdb6a_row46_col46, #T_cdb6a_row47_col47, #T_cdb6a_row48_col48, #T_cdb6a_row49_col49, #T_cdb6a_row50_col50, #T_cdb6a_row51_col51, #T_cdb6a_row52_col52, #T_cdb6a_row53_col53, #T_cdb6a_row54_col54, #T_cdb6a_row55_col55, #T_cdb6a_row56_col56, #T_cdb6a_row57_col57, #T_cdb6a_row58_col58, #T_cdb6a_row59_col59, #T_cdb6a_row60_col60, #T_cdb6a_row61_col61, #T_cdb6a_row62_col62, #T_cdb6a_row63_col63, #T_cdb6a_row64_col64, #T_cdb6a_row65_col65, #T_cdb6a_row66_col66, #T_cdb6a_row67_col67, #T_cdb6a_row68_col68, #T_cdb6a_row69_col69, #T_cdb6a_row70_col70, #T_cdb6a_row71_col71, #T_cdb6a_row72_col72, #T_cdb6a_row73_col73, #T_cdb6a_row74_col74, #T_cdb6a_row75_col75, #T_cdb6a_row76_col76, #T_cdb6a_row77_col77, #T_cdb6a_row78_col78, #T_cdb6a_row79_col79, #T_cdb6a_row80_col80, #T_cdb6a_row81_col81, #T_cdb6a_row82_col82, #T_cdb6a_row83_col83, #T_cdb6a_row84_col84, #T_cdb6a_row85_col85, #T_cdb6a_row86_col86, #T_cdb6a_row87_col87, #T_cdb6a_row88_col88, #T_cdb6a_row89_col89 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cdb6a_row0_col1, #T_cdb6a_row1_col0, #T_cdb6a_row3_col77, #T_cdb6a_row4_col34, #T_cdb6a_row4_col77, #T_cdb6a_row5_col8, #T_cdb6a_row5_col45, #T_cdb6a_row5_col52, #T_cdb6a_row7_col8, #T_cdb6a_row8_col0, #T_cdb6a_row8_col35, #T_cdb6a_row8_col74, #T_cdb6a_row8_col87, #T_cdb6a_row8_col89, #T_cdb6a_row9_col34, #T_cdb6a_row9_col77, #T_cdb6a_row9_col83, #T_cdb6a_row10_col13, #T_cdb6a_row10_col16, #T_cdb6a_row11_col77, #T_cdb6a_row11_col89, #T_cdb6a_row13_col82, #T_cdb6a_row14_col9, #T_cdb6a_row14_col77, #T_cdb6a_row14_col89, #T_cdb6a_row15_col0, #T_cdb6a_row15_col68, #T_cdb6a_row16_col14, #T_cdb6a_row17_col28, #T_cdb6a_row17_col68, #T_cdb6a_row19_col9, #T_cdb6a_row19_col24, #T_cdb6a_row19_col77, #T_cdb6a_row19_col89, #T_cdb6a_row21_col89, #T_cdb6a_row22_col57, #T_cdb6a_row23_col14, #T_cdb6a_row23_col49, #T_cdb6a_row24_col9, #T_cdb6a_row24_col82, #T_cdb6a_row25_col35, #T_cdb6a_row25_col53, #T_cdb6a_row26_col68, #T_cdb6a_row26_col71, #T_cdb6a_row26_col89, #T_cdb6a_row27_col0, #T_cdb6a_row27_col53, #T_cdb6a_row28_col14, #T_cdb6a_row29_col34, #T_cdb6a_row29_col77, #T_cdb6a_row29_col83, #T_cdb6a_row30_col41, #T_cdb6a_row30_col89, #T_cdb6a_row31_col74, #T_cdb6a_row32_col41, #T_cdb6a_row33_col0, #T_cdb6a_row33_col89, #T_cdb6a_row34_col9, #T_cdb6a_row36_col1, #T_cdb6a_row36_col77, #T_cdb6a_row37_col14, #T_cdb6a_row38_col14, #T_cdb6a_row39_col9, #T_cdb6a_row39_col34, #T_cdb6a_row39_col77, #T_cdb6a_row39_col83, #T_cdb6a_row40_col48, #T_cdb6a_row40_col74, #T_cdb6a_row40_col89, #T_cdb6a_row41_col14, #T_cdb6a_row41_col89, #T_cdb6a_row42_col48, #T_cdb6a_row42_col74, #T_cdb6a_row42_col89, #T_cdb6a_row43_col49, #T_cdb6a_row44_col77, #T_cdb6a_row45_col53, #T_cdb6a_row46_col77, #T_cdb6a_row47_col49, #T_cdb6a_row47_col53, #T_cdb6a_row47_col89, #T_cdb6a_row48_col14, #T_cdb6a_row49_col59, #T_cdb6a_row49_col82, #T_cdb6a_row50_col41, #T_cdb6a_row50_col89, #T_cdb6a_row51_col89, #T_cdb6a_row52_col41, #T_cdb6a_row52_col87, #T_cdb6a_row52_col89, #T_cdb6a_row54_col77, #T_cdb6a_row55_col60, #T_cdb6a_row57_col49, #T_cdb6a_row58_col49, #T_cdb6a_row58_col60, #T_cdb6a_row60_col14, #T_cdb6a_row60_col74, #T_cdb6a_row61_col89, #T_cdb6a_row62_col0, #T_cdb6a_row62_col14, #T_cdb6a_row62_col35, #T_cdb6a_row62_col89, #T_cdb6a_row63_col77, #T_cdb6a_row64_col59, #T_cdb6a_row65_col71, #T_cdb6a_row66_col41, #T_cdb6a_row66_col89, #T_cdb6a_row67_col71, #T_cdb6a_row68_col49, #T_cdb6a_row68_col87, #T_cdb6a_row69_col44, #T_cdb6a_row69_col59, #T_cdb6a_row69_col77, #T_cdb6a_row70_col58, #T_cdb6a_row70_col89, #T_cdb6a_row71_col89, #T_cdb6a_row72_col58, #T_cdb6a_row73_col82, #T_cdb6a_row74_col77, #T_cdb6a_row75_col89, #T_cdb6a_row76_col49, #T_cdb6a_row78_col14, #T_cdb6a_row79_col59, #T_cdb6a_row79_col77, #T_cdb6a_row80_col14, #T_cdb6a_row80_col35, #T_cdb6a_row80_col49, #T_cdb6a_row82_col14, #T_cdb6a_row83_col14, #T_cdb6a_row83_col87, #T_cdb6a_row84_col74, #T_cdb6a_row85_col29, #T_cdb6a_row85_col44, #T_cdb6a_row85_col74, #T_cdb6a_row86_col4, #T_cdb6a_row88_col14, #T_cdb6a_row89_col68 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_cdb6a_row0_col2, #T_cdb6a_row1_col57, #T_cdb6a_row2_col55, #T_cdb6a_row9_col57, #T_cdb6a_row11_col57, #T_cdb6a_row14_col57, #T_cdb6a_row14_col70, #T_cdb6a_row16_col45, #T_cdb6a_row19_col57, #T_cdb6a_row19_col70, #T_cdb6a_row21_col5, #T_cdb6a_row23_col47, #T_cdb6a_row24_col57, #T_cdb6a_row28_col22, #T_cdb6a_row31_col10, #T_cdb6a_row33_col75, #T_cdb6a_row34_col57, #T_cdb6a_row34_col70, #T_cdb6a_row37_col57, #T_cdb6a_row39_col57, #T_cdb6a_row39_col70, #T_cdb6a_row40_col20, #T_cdb6a_row41_col5, #T_cdb6a_row41_col72, #T_cdb6a_row42_col22, #T_cdb6a_row44_col57, #T_cdb6a_row53_col12, #T_cdb6a_row54_col57, #T_cdb6a_row56_col7, #T_cdb6a_row56_col52, #T_cdb6a_row59_col57, #T_cdb6a_row60_col5, #T_cdb6a_row61_col57, #T_cdb6a_row62_col72, #T_cdb6a_row63_col55, #T_cdb6a_row64_col57, #T_cdb6a_row72_col33, #T_cdb6a_row78_col5, #T_cdb6a_row80_col42, #T_cdb6a_row81_col30, #T_cdb6a_row81_col42, #T_cdb6a_row82_col10, #T_cdb6a_row82_col30, #T_cdb6a_row82_col50, #T_cdb6a_row83_col57, #T_cdb6a_row84_col70, #T_cdb6a_row85_col32, #T_cdb6a_row86_col5, #T_cdb6a_row86_col40, #T_cdb6a_row86_col57, #T_cdb6a_row88_col5, #T_cdb6a_row88_col57 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_cdb6a_row0_col3, #T_cdb6a_row0_col4, #T_cdb6a_row0_col53, #T_cdb6a_row2_col28, #T_cdb6a_row2_col63, #T_cdb6a_row2_col64, #T_cdb6a_row3_col53, #T_cdb6a_row4_col64, #T_cdb6a_row5_col28, #T_cdb6a_row5_col63, #T_cdb6a_row5_col64, #T_cdb6a_row7_col28, #T_cdb6a_row7_col63, #T_cdb6a_row7_col64, #T_cdb6a_row8_col88, #T_cdb6a_row10_col28, #T_cdb6a_row10_col63, #T_cdb6a_row10_col64, #T_cdb6a_row11_col63, #T_cdb6a_row12_col63, #T_cdb6a_row12_col64, #T_cdb6a_row14_col39, #T_cdb6a_row14_col53, #T_cdb6a_row14_col64, #T_cdb6a_row15_col41, #T_cdb6a_row15_col55, #T_cdb6a_row15_col57, #T_cdb6a_row15_col63, #T_cdb6a_row15_col64, #T_cdb6a_row15_col87, #T_cdb6a_row16_col64, #T_cdb6a_row17_col41, #T_cdb6a_row17_col63, #T_cdb6a_row17_col64, #T_cdb6a_row19_col4, #T_cdb6a_row19_col39, #T_cdb6a_row19_col63, #T_cdb6a_row20_col13, #T_cdb6a_row20_col35, #T_cdb6a_row20_col43, #T_cdb6a_row20_col47, #T_cdb6a_row20_col63, #T_cdb6a_row20_col64, #T_cdb6a_row21_col63, #T_cdb6a_row21_col64, #T_cdb6a_row22_col43, #T_cdb6a_row22_col63, #T_cdb6a_row22_col64, #T_cdb6a_row22_col71, #T_cdb6a_row23_col3, #T_cdb6a_row24_col4, #T_cdb6a_row24_col63, #T_cdb6a_row24_col64, #T_cdb6a_row25_col64, #T_cdb6a_row26_col63, #T_cdb6a_row26_col73, #T_cdb6a_row27_col64, #T_cdb6a_row28_col64, #T_cdb6a_row29_col4, #T_cdb6a_row29_col63, #T_cdb6a_row29_col64, #T_cdb6a_row30_col57, #T_cdb6a_row30_col63, #T_cdb6a_row30_col64, #T_cdb6a_row30_col65, #T_cdb6a_row30_col71, #T_cdb6a_row31_col63, #T_cdb6a_row32_col63, #T_cdb6a_row32_col64, #T_cdb6a_row32_col71, #T_cdb6a_row34_col4, #T_cdb6a_row34_col63, #T_cdb6a_row35_col38, #T_cdb6a_row35_col39, #T_cdb6a_row35_col53, #T_cdb6a_row36_col64, #T_cdb6a_row37_col28, #T_cdb6a_row38_col53, #T_cdb6a_row38_col64, #T_cdb6a_row39_col63, #T_cdb6a_row39_

# %%
mask_gt = correlation_matrix >= 0.8 
mask_lt = correlation_matrix <= -0.8

# %%
features_correlated = []
for i, row in enumerate(correlation_matrix.index):
    for j, column in enumerate(correlation_matrix.columns):
        if mask_gt.loc[row, column] or mask_lt.loc[row, column]:
            if  i < j:
                features_correlated.append((row, column))
features_correlated
# Out:
# [('pmax[1]', 'area[1]'),
#  ('pmax[3]', 'area[3]'),
#  ('pmax[4]', 'area[4]'),
#  ('pmax[5]', 'negpmax[5]'),
#  ('pmax[5]', 'area[5]'),
#  ('negpmax[5]', 'area[5]'),
#  ('pmax[6]', 'area[6]'),
#  ('pmax[8]', 'area[8]'),
#  ('pmax[9]', 'area[9]'),
#  ('pmax[10]', 'area[10]'),
#  ('pmax[11]', 'area[11]'),
#  ('pmax[13]', 'area[13]'),
#  ('pmax[14]', 'area[14]'),
#  ('tmax[15]', 'tmax[16]'),
#  ('tmax[15]', 'tmax[17]'),
#  ('tmax[16]', 'tmax[17]')]

# %% [markdown]
# We will handle highly correlated features later with PCA

# %% [markdown]
# ## Outliers
# We have a multivariate problem, so We will detect outliers using Isolation Forest.
# We considered the following documentation, for choosing the outlier detector: https://scikit-learn.org/stable/modules/outlier_detection.html#overview-of-outlier-detection-methods

# %%
isolation_forest = IsolationForest(n_estimators=1000)
X_train['is_outlier'] = isolation_forest.fit_predict(X_train) # fit_predict returns -1 for outliers and 1 for inliers

# %%
X_train['is_outlier'].value_counts() 
# 2029 n_estimators=100
# 2809 n_estimators=1000
# 2544 n_estimators=10000
# Out:
# is_outlier
#  1    267636
# -1      2214
# Name: count, dtype: int64

# %%
mask_is_outlier = X_train['is_outlier'] == -1
plt.scatter(y_train.x[~mask_is_outlier], y_train.y[~mask_is_outlier], c='orange', label='inliers')
plt.scatter(y_train.x[mask_is_outlier], y_train.y[mask_is_outlier], c='red', label='outliers', alpha=0.3)

plt.show()

# %%
X_train_without_outliers, y_train_without_outliers = X_train[~mask_is_outlier], y_train[~mask_is_outlier]
del(X_train_without_outliers['is_outlier'])
del(X_train['is_outlier'])

# %%
# Let's reset the index
X_train_without_outliers.reset_index(drop=True, inplace=True)
y_train_without_outliers.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Normalization

# %%
scaler_without_outliers = StandardScaler()
scaler = StandardScaler()

X_train_without_outliers_scaled = scaler_without_outliers.fit_transform(X_train_without_outliers)
X_train_scaled = scaler.fit_transform(X_train)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_train_without_outliers_scaled = pd.DataFrame(X_train_without_outliers_scaled, columns=X_train.columns)

# %% [markdown]
# # PCA

# %%
pca = PCA()
pca_without_outliers = PCA()

pca.fit(X_train_scaled)
pca_without_outliers.fit(X_train_without_outliers_scaled)

plt.figure(figsize=(20,8))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.plot(np.cumsum(pca_without_outliers.explained_variance_ratio_))
# plt.xticks(ticks=np.arange(pca.n_features_), 
#             labels=[f'PC{i + 1}' for i in range(pca.n_features_)])


# plt.figure(figsize=(20,8))
# plt.plot(np.cumsum(pca.explained_variance_ratio_))
# plt.title('Xworkdf')
# #plt.ylim([0, 1.1])
# plt.xticks(ticks=np.arange(pca.n_features_), 
#            labels=[f'PC{i + 1}' for i in range(pca.n_features_)])
# plt.xlabel('Principal components')
# plt.ylabel('Cumulative explained variance')
# plt.grid()
# plt.show()

# %%
print(np.cumsum(pca.explained_variance_ratio_))
print(np.cumsum(pca_without_outliers.explained_variance_ratio_))
# Out:
# [0.09265431 0.17189915 0.20840624 0.24277017 0.2701079  0.29147687
#  0.3092045  0.32536225 0.34117631 0.35649147 0.37024946 0.38317385
#  0.39580491 0.40830884 0.42069668 0.4328985  0.44492961 0.45683976
#  0.46850847 0.48003572 0.49155268 0.50293178 0.51427085 0.52551907
#  0.53672811 0.54790585 0.5590589  0.57019881 0.58132065 0.59241924
#  0.60350962 0.61456927 0.62561931 0.63665448 0.64766916 0.65867167
#  0.66965836 0.68061588 0.69155481 0.70244595 0.71330107 0.72406319
#  0.73478183 0.74538089 0.75589097 0.76629629 0.7766554  0.78698371
#  0.7972071  0.80739681 0.81748269 0.82752806 0.83749376 0.84740841
#  0.85724503 0.86700581 0.87673854 0.88630605 0.89578127 0.90518669
#  0.91444404 0.92346204 0.93225638 0.94079499 0.94894872 0.95675644
#  0.96336263 0.96959502 0.97542439 0.98011166 0.98459657 0.98807887
#  0.9908995  0.99244697 0.99385347 0.99501665 0.99577816 0.99639204
#  0.99697366 0.99746321 0.99792591 0.99827968 0.99858783 0.99886432
#  0.99911558 0.99936265 0.99958155 0.99977892 0.99997332 1.        ]
# [0.09270926 0.17201142 0.20845159 0.24288404 0.2701367  0.29145058
#  0.30914394 0.32528506 0.34105534 0.35635463 0.36930263 0.38198864
#  0.39451279 0.40693883 0.41915423 0.43129723 0.44327054 0.45510189
#  0.46677461 0.47831626 0.48972904 0.50106456 0.51235702 0.5236183
#  0.53485906 0.54605541 0.55722933 0.56839203 0.5795282  0.59063983
#  0.60173841 0.61282564 0.62390993 0.63498412 0.64602997 0.657051
#  0.66806445 0.67907153 0.69005055 0.70098012 0.71186065 0.72267615
#  0.73343136 0.74405731 0.75466371 0.7651907  0.77560869 0.78595408
#  0.79627083 0.8065047  0.81668218 0.82678002 0.83685448 0.84680181
#  0.85671838 0.86656604 0.87633924 0.88597507 0.89555405 0.90504498
#  0.91437589 0.92339522 0.93225117 0.94079244 0.94891561 0.95672344
#  0.9633272  0.96955469 0.97538235 0.98008401 0.98456992 0.98805339
#  0.99089961 0.99245065 0.99385871 0.99502598 0.99578968 0.99640676
#  0.99699144 0.9974831  0.99792923 0.99828423 0.99859208 0.99886896
#  0.99912055 0.99936774 0.99958655 0.99978177 0.99997333 1.        ]

# %%
def findm(pca):
        m=0
        for i,var in enumerate(np.cumsum(pca.explained_variance_ratio_)):
                if var>=0.99:        
                        m=i+1 #It is +1 because the counting starts from 0
                        break    
        return m

# %%
n = findm(pca)
n_without_outliers = findm(pca_without_outliers)
n
print(f"n = {n} and n_without_outliers = {n_without_outliers}")
# Out:
# n = 73 and n_without_outliers = 73

# %%
pca = PCA(n_components=n)
pca_without_outliers = PCA(n_components=n_without_outliers)

pca.fit(X_train_scaled)
pca_without_outliers.fit(X_train_without_outliers_scaled)
# Out:
# PCA(n_components=60)

# %%
X_train_pca = pca.transform(X_train_scaled)
X_train_without_outliers_pca = pca_without_outliers.transform(X_train_without_outliers_scaled)

# %%
X_train_pca = pd.DataFrame(X_train_pca, columns=[f'PC{i + 1}' for i in range(n)])
X_train_without_outliers_pca = pd.DataFrame(X_train_without_outliers_pca, columns=[f'PC{i + 1}' for i in range(n_without_outliers)])

# %%
# Download the datasets with outliers and without outliers respectively
pd.concat([X_train, y_train], axis=1).to_csv(path + 'train.csv', index=False)
pd.concat([X_train_without_outliers, y_train_without_outliers], axis=1).to_csv(path + 'train_without_outliers.csv', index=False)

# Download the datasets scaled with outliers and without outliers respectively
pd.concat([X_train_scaled, y_train], axis=1).to_csv(path + 'train_scaled.csv', index=False)
pd.concat([X_train_without_outliers_scaled, y_train_without_outliers], axis=1).to_csv(path + 'train_without_outliers_scaled.csv', index=False)

# Download the datasets scaled and pca with outliers and without outliers respectively
pd.concat([X_train_pca, y_train], axis=1).to_csv(path + 'train_pca.csv', index=False)
pd.concat([X_train_without_outliers_pca, y_train_without_outliers], axis=1).to_csv(path + 'train_without_outliers_pca.csv', index=False)

# %%
# Download the test set
pd.concat([X_test, y_test], axis=1).to_csv(path + 'test.csv', index=False)

# %%
X_test = pd.read_csv(path + 'evaluation.csv', index_col=0)

# %%
X_test.head()

# %%
X_test_scaled = scaler_without_outliers.transform(X_test)

# %%
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
X_test_scaled.head()

# %%
X_test_pca = pca_without_outliers.transform(X_test_scaled)
X_test_pca = pd.DataFrame(X_test_pca, columns=[f'PC{i + 1}' for i in range(n_without_outliers)])

# %%
X_test_pca.head()

# %%
X_test_pca.to_csv(path + 'evaluation_pca.csv', index=True)
