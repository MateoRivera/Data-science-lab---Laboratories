# %% [markdown]
# ## Libraries

# %%
# For handling data
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# For plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# For Outlier Detection
from sklearn.ensemble import IsolationForest

# For Dimensionality Reduction
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# ## Reading the database ```development.csv```

# %%
path = './DSL_Winter_Project_2024/'
df = pd.read_csv(path + 'development.csv')

# %%
# Let's see what we have
df.head()
# Out:
#        x      y   pmax[0]  negpmax[0]   area[0]     tmax[0]    rms[0]  \
# 0  200.0  200.0  4.066907  -17.690173  2.847932    0.600000  2.007042
# 1  200.0  200.0  5.916801   -4.717111  5.792778   79.765174  1.564535
# 2  200.0  200.0  4.286652   -5.316132  2.356390   74.600000  1.404622
# 3  200.0  200.0  4.003635   -4.617459  2.189005   43.000000  1.512162
# 4  200.0  200.0  4.448146   -4.848743  3.997002  196.667482  1.101113
#
#     pmax[1]  negpmax[1]   area[1]  ...    pmax[16]  negpmax[16]    area[16]  \
# 0  5.409161  -17.721210  4.538778  ...  607.109118   -36.282996  583.899899
# 1  4.414289   -4.736827  3.720435  ...  630.348007   -39.715988  580.042799
# 2  4.567191   -5.985437  3.490490  ...  613.880342   -40.679678  580.407491
# 3  5.019058   -4.229949  6.786200  ...  600.714957   -43.206601  579.882635
# 4  3.250262   -5.783587  2.449456  ...  609.723785   -43.570892  590.156125
#
#     tmax[16]   rms[16]    pmax[17]  negpmax[17]    area[17]   tmax[17]  \
# 0  72.373094  0.374498  614.916861   -39.848523  591.852768  72.331028
# 1  71.029155  0.403258  624.950701   -41.266681  586.569646  71.089058
# 2  71.892264  0.568777  596.437125   -42.712286  574.091695  71.943934
# 3  72.357388  0.255483  591.763739   -50.681940  584.099483  72.333282
# 4  71.249130  0.413855  606.917023   -49.923819  584.316142  71.242904
#
#     rms[17]
# 0  0.405595
# 1  0.405890
# 2  0.498019
# 3  0.336454
# 4  0.293824
#
# [5 rows x 92 columns]

# %%
# Let's split the data into X and y (We have two variables to predict: x and y)
X = df.loc[:, 'pmax[0]':]
y = df[['x', 'y']]

# %%
# Let's split X, y1 and y2 into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Let's reset the indices
X_train.reset_index(drop=True, inplace=True)
X_test.reset_index(drop=True, inplace=True)

y_train.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)

# %%
# There is not na data
X_train.isna().sum().sum()
# Out:
# 0

# %%
X_train['pmax[0]'].hist()
# Out:
# <AxesSubplot: >

# %%
X_train['negpmax[0]'].hist()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Correlation data

# %%
correlation_matrix = X_train.corr()
correlation_matrix
# Out:
#               pmax[0]  negpmax[0]   area[0]   tmax[0]    rms[0]   pmax[1]  \
# pmax[0]      1.000000    0.025220  0.326791  0.011399  0.011369  0.039061
# negpmax[0]   0.025220    1.000000  0.034223  0.007014 -0.006160  0.000352
# area[0]      0.326791    0.034223  1.000000  0.022664 -0.004130  0.004314
# tmax[0]      0.011399    0.007014  0.022664  1.000000 -0.061725 -0.002889
# rms[0]       0.011369   -0.006160 -0.004130 -0.061725  1.000000 -0.001507
# ...               ...         ...       ...       ...       ...       ...
# pmax[17]     0.005724    0.000906  0.001377 -0.002618  0.011373  0.013361
# negpmax[17]  0.015272    0.005355  0.011008  0.012378 -0.020340  0.011779
# area[17]     0.016521    0.007341  0.002038  0.002610  0.003360  0.046078
# tmax[17]     0.048253    0.000168  0.011230  0.010810 -0.005771  0.006667
# rms[17]     -0.003998   -0.003696 -0.005892 -0.004488  0.004802 -0.004983
#
#              negpmax[1]   area[1]   tmax[1]    rms[1]  ...  pmax[16]  \
# pmax[0]        0.003213  0.036198  0.024983 -0.000750  ...  0.019361
# negpmax[0]     0.008121  0.001411  0.004702  0.004521  ... -0.001200
# area[0]        0.004754  0.005434  0.001119 -0.003655  ...  0.005586
# tmax[0]        0.001839 -0.004366  0.017980 -0.005055  ...  0.004560
# rms[0]        -0.001030 -0.001187 -0.000702  0.013783  ... -0.002539
# ...                 ...       ...       ...       ...  ...       ...
# pmax[17]      -0.003075  0.011035 -0.001545  0.008675  ... -0.040089
# negpmax[17]    0.000365  0.015090 -0.001251 -0.011999  ... -0.008652
# area[17]      -0.005218  0.047806 -0.010867  0.003945  ... -0.033969
# tmax[17]      -0.002275  0.007923  0.021141 -0.009039  ... -0.022465
# rms[17]       -0.001114 -0.007643  0.002292  0.003288  ... -0.013877
#
#              negpmax[16]  area[16]  tmax[16]   rms[16]  pmax[17]  negpmax[17]  \
# pmax[0]         0.016773  0.041410  0.042877  0.012654  0.005724     0.015272
# negpmax[0]     -0.013337  0.004160  0.001720  0.008998  0.000906     0.005355
# area[0]        -0.004767  0.005432  0.009526 -0.000988  0.001377     0.011008
# tmax[0]         0.001840  0.001066  0.004105 -0.011122 -0.002618     0.012378
# rms[0]          0.001456 -0.005963 -0.004402  0.026901  0.011373    -0.020340
# ...                  ...       ...       ...       ...       ...          ...
# pmax[17]        0.033041 -0.018158 -0.038456  0.102175  1.000000    -0.209484
# negpmax[17]     0.013383  0.101008  0.038763 -0.125064 -0.209484     1.000000
# area[17]        0.063484  0.128035 -0.011428 -0.008240  0.078457    -0.049829
# tmax[17]        0.019311  0.078339  0.983039 -0.017391 -0.051784     0.052719
# rms[17]        -0.000886 -0.037236  0.005647 -0.024990 -0.002933    -0.011154
#
#              area[17]  tmax[17]   rms[17]
# pmax[0]      0.016521  0.048253 -0.003998
# negpmax[0]   0.007341  0.000168 -0.003696
# area[0]      0.002038  0.011230 -0.005892
# tmax[0]      0.002610  0.010810 -0.004488
# rms[0]       0.003360 -0.005771  0.004802
# ...               ...       ...       ...
# pmax[17]     0.078457 -0.051784 -0.002933
# negpmax[17] -0.049829  0.052719 -0.011154
# area[17]     1.000000 -0.008443 -0.020885
# tmax[17]    -0.008443  1.000000 -0.002411
# rms[17]     -0.020885 -0.002411  1.000000
#
# [90 rows x 90 columns]

# %%
corr = correlation_matrix
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c8003_row0_col0, #T_c8003_row1_col1, #T_c8003_row2_col2, #T_c8003_row3_col3, #T_c8003_row4_col4, #T_c8003_row5_col5, #T_c8003_row6_col6, #T_c8003_row7_col7, #T_c8003_row8_col8, #T_c8003_row9_col9, #T_c8003_row10_col10, #T_c8003_row11_col11, #T_c8003_row12_col12, #T_c8003_row13_col13, #T_c8003_row14_col14, #T_c8003_row15_col15, #T_c8003_row16_col16, #T_c8003_row17_col17, #T_c8003_row18_col18, #T_c8003_row19_col19, #T_c8003_row20_col20, #T_c8003_row21_col21, #T_c8003_row22_col22, #T_c8003_row23_col23, #T_c8003_row24_col24, #T_c8003_row25_col25, #T_c8003_row26_col26, #T_c8003_row27_col27, #T_c8003_row28_col28, #T_c8003_row29_col29, #T_c8003_row30_col30, #T_c8003_row31_col31, #T_c8003_row32_col32, #T_c8003_row33_col33, #T_c8003_row34_col34, #T_c8003_row35_col35, #T_c8003_row36_col36, #T_c8003_row37_col37, #T_c8003_row38_col38, #T_c8003_row39_col39, #T_c8003_row40_col40, #T_c8003_row41_col41, #T_c8003_row42_col42, #T_c8003_row43_col43, #T_c8003_row44_col44, #T_c8003_row45_col45, #T_c8003_row46_col46, #T_c8003_row47_col47, #T_c8003_row48_col48, #T_c8003_row49_col49, #T_c8003_row50_col50, #T_c8003_row51_col51, #T_c8003_row52_col52, #T_c8003_row53_col53, #T_c8003_row54_col54, #T_c8003_row55_col55, #T_c8003_row56_col56, #T_c8003_row57_col57, #T_c8003_row58_col58, #T_c8003_row59_col59, #T_c8003_row60_col60, #T_c8003_row61_col61, #T_c8003_row62_col62, #T_c8003_row63_col63, #T_c8003_row64_col64, #T_c8003_row65_col65, #T_c8003_row66_col66, #T_c8003_row67_col67, #T_c8003_row68_col68, #T_c8003_row69_col69, #T_c8003_row70_col70, #T_c8003_row71_col71, #T_c8003_row72_col72, #T_c8003_row73_col73, #T_c8003_row74_col74, #T_c8003_row75_col75, #T_c8003_row76_col76, #T_c8003_row77_col77, #T_c8003_row78_col78, #T_c8003_row79_col79, #T_c8003_row80_col80, #T_c8003_row81_col81, #T_c8003_row82_col82, #T_c8003_row83_col83, #T_c8003_row84_col84, #T_c8003_row85_col85, #T_c8003_row86_col86, #T_c8003_row87_col87, #T_c8003_row88_col88, #T_c8003_row89_col89 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c8003_row0_col1, #T_c8003_row1_col0, #T_c8003_row3_col77, #T_c8003_row4_col34, #T_c8003_row4_col77, #T_c8003_row5_col8, #T_c8003_row5_col45, #T_c8003_row5_col52, #T_c8003_row7_col8, #T_c8003_row8_col0, #T_c8003_row8_col35, #T_c8003_row8_col74, #T_c8003_row8_col87, #T_c8003_row8_col89, #T_c8003_row9_col34, #T_c8003_row9_col77, #T_c8003_row9_col83, #T_c8003_row10_col13, #T_c8003_row10_col16, #T_c8003_row11_col77, #T_c8003_row11_col89, #T_c8003_row13_col82, #T_c8003_row14_col9, #T_c8003_row14_col77, #T_c8003_row14_col89, #T_c8003_row15_col0, #T_c8003_row15_col68, #T_c8003_row16_col14, #T_c8003_row17_col28, #T_c8003_row17_col68, #T_c8003_row19_col9, #T_c8003_row19_col24, #T_c8003_row19_col77, #T_c8003_row19_col89, #T_c8003_row21_col89, #T_c8003_row22_col57, #T_c8003_row23_col14, #T_c8003_row23_col49, #T_c8003_row24_col9, #T_c8003_row24_col82, #T_c8003_row25_col35, #T_c8003_row25_col53, #T_c8003_row26_col68, #T_c8003_row26_col71, #T_c8003_row26_col89, #T_c8003_row27_col0, #T_c8003_row27_col53, #T_c8003_row28_col14, #T_c8003_row29_col34, #T_c8003_row29_col77, #T_c8003_row29_col83, #T_c8003_row30_col41, #T_c8003_row30_col89, #T_c8003_row31_col74, #T_c8003_row32_col41, #T_c8003_row33_col0, #T_c8003_row33_col89, #T_c8003_row34_col9, #T_c8003_row36_col1, #T_c8003_row36_col77, #T_c8003_row37_col14, #T_c8003_row38_col14, #T_c8003_row39_col9, #T_c8003_row39_col34, #T_c8003_row39_col77, #T_c8003_row39_col83, #T_c8003_row40_col48, #T_c8003_row40_col74, #T_c8003_row40_col89, #T_c8003_row41_col14, #T_c8003_row41_col89, #T_c8003_row42_col48, #T_c8003_row42_col74, #T_c8003_row42_col89, #T_c8003_row43_col49, #T_c8003_row44_col77, #T_c8003_row45_col53, #T_c8003_row46_col77, #T_c8003_row47_col49, #T_c8003_row47_col53, #T_c8003_row47_col89, #T_c8003_row48_col14, #T_c8003_row49_col59, #T_c8003_row49_col82, #T_c8003_row50_col41, #T_c8003_row50_col89, #T_c8003_row51_col89, #T_c8003_row52_col41, #T_c8003_row52_col87, #T_c8003_row52_col89, #T_c8003_row54_col77, #T_c8003_row55_col60, #T_c8003_row57_col49, #T_c8003_row58_col49, #T_c8003_row58_col60, #T_c8003_row60_col14, #T_c8003_row60_col74, #T_c8003_row61_col89, #T_c8003_row62_col0, #T_c8003_row62_col14, #T_c8003_row62_col35, #T_c8003_row62_col89, #T_c8003_row63_col77, #T_c8003_row64_col59, #T_c8003_row65_col71, #T_c8003_row66_col41, #T_c8003_row66_col89, #T_c8003_row67_col71, #T_c8003_row68_col49, #T_c8003_row68_col87, #T_c8003_row69_col44, #T_c8003_row69_col59, #T_c8003_row69_col77, #T_c8003_row70_col58, #T_c8003_row70_col89, #T_c8003_row71_col89, #T_c8003_row72_col58, #T_c8003_row73_col82, #T_c8003_row74_col77, #T_c8003_row75_col89, #T_c8003_row76_col49, #T_c8003_row78_col14, #T_c8003_row79_col59, #T_c8003_row79_col77, #T_c8003_row80_col14, #T_c8003_row80_col35, #T_c8003_row80_col49, #T_c8003_row82_col14, #T_c8003_row83_col14, #T_c8003_row83_col87, #T_c8003_row84_col74, #T_c8003_row85_col29, #T_c8003_row85_col44, #T_c8003_row85_col74, #T_c8003_row86_col4, #T_c8003_row88_col14, #T_c8003_row89_col68 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_c8003_row0_col2, #T_c8003_row1_col57, #T_c8003_row2_col55, #T_c8003_row9_col57, #T_c8003_row11_col57, #T_c8003_row14_col57, #T_c8003_row14_col70, #T_c8003_row16_col45, #T_c8003_row19_col57, #T_c8003_row19_col70, #T_c8003_row21_col5, #T_c8003_row23_col47, #T_c8003_row24_col57, #T_c8003_row28_col22, #T_c8003_row31_col10, #T_c8003_row33_col75, #T_c8003_row34_col57, #T_c8003_row34_col70, #T_c8003_row37_col57, #T_c8003_row39_col57, #T_c8003_row39_col70, #T_c8003_row40_col20, #T_c8003_row41_col5, #T_c8003_row41_col72, #T_c8003_row42_col22, #T_c8003_row44_col57, #T_c8003_row53_col12, #T_c8003_row54_col57, #T_c8003_row56_col7, #T_c8003_row56_col52, #T_c8003_row59_col57, #T_c8003_row60_col5, #T_c8003_row61_col57, #T_c8003_row62_col72, #T_c8003_row63_col55, #T_c8003_row64_col57, #T_c8003_row72_col33, #T_c8003_row78_col5, #T_c8003_row80_col42, #T_c8003_row81_col30, #T_c8003_row81_col42, #T_c8003_row82_col10, #T_c8003_row82_col30, #T_c8003_row82_col50, #T_c8003_row83_col57, #T_c8003_row84_col70, #T_c8003_row85_col32, #T_c8003_row86_col5, #T_c8003_row86_col40, #T_c8003_row86_col57, #T_c8003_row88_col5, #T_c8003_row88_col57 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_c8003_row0_col3, #T_c8003_row0_col4, #T_c8003_row0_col53, #T_c8003_row2_col28, #T_c8003_row2_col63, #T_c8003_row2_col64, #T_c8003_row3_col53, #T_c8003_row4_col64, #T_c8003_row5_col28, #T_c8003_row5_col63, #T_c8003_row5_col64, #T_c8003_row7_col28, #T_c8003_row7_col63, #T_c8003_row7_col64, #T_c8003_row8_col88, #T_c8003_row10_col28, #T_c8003_row10_col63, #T_c8003_row10_col64, #T_c8003_row11_col63, #T_c8003_row12_col63, #T_c8003_row12_col64, #T_c8003_row14_col39, #T_c8003_row14_col53, #T_c8003_row14_col64, #T_c8003_row15_col41, #T_c8003_row15_col55, #T_c8003_row15_col57, #T_c8003_row15_col63, #T_c8003_row15_col64, #T_c8003_row15_col87, #T_c8003_row16_col64, #T_c8003_row17_col41, #T_c8003_row17_col63, #T_c8003_row17_col64, #T_c8003_row19_col4, #T_c8003_row19_col39, #T_c8003_row19_col63, #T_c8003_row20_col13, #T_c8003_row20_col35, #T_c8003_row20_col43, #T_c8003_row20_col47, #T_c8003_row20_col63, #T_c8003_row20_col64, #T_c8003_row21_col63, #T_c8003_row21_col64, #T_c8003_row22_col43, #T_c8003_row22_col63, #T_c8003_row22_col64, #T_c8003_row22_col71, #T_c8003_row23_col3, #T_c8003_row24_col4, #T_c8003_row24_col63, #T_c8003_row24_col64, #T_c8003_row25_col64, #T_c8003_row26_col63, #T_c8003_row26_col73, #T_c8003_row27_col64, #T_c8003_row28_col64, #T_c8003_row29_col4, #T_c8003_row29_col63, #T_c8003_row29_col64, #T_c8003_row30_col57, #T_c8003_row30_col63, #T_c8003_row30_col64, #T_c8003_row30_col65, #T_c8003_row30_col71, #T_c8003_row31_col63, #T_c8003_row32_col63, #T_c8003_row32_col64, #T_c8003_row32_col71, #T_c8003_row34_col4, #T_c8003_row34_col63, #T_c8003_row35_col38, #T_c8003_row35_col39, #T_c8003_row35_col53, #T_c8003_row36_col64, #T_c8003_row37_col28, #T_c8003_row38_col53, #T_c8003_row38_col64, #T_c8003_row39_col63, #T_c8003_row39_

# %%
mask_gt = correlation_matrix >= 0.8 
mask_lt = correlation_matrix <= -0.8

# %%
features_correlated = []
for i, row in enumerate(correlation_matrix.index):
    for j, column in enumerate(correlation_matrix.columns):
        if mask_gt.loc[row, column] or mask_lt.loc[row, column]:
            if  i < j:
                features_correlated.append((row, column))
features_correlated
# Out:
# [('pmax[1]', 'area[1]'),
#  ('pmax[3]', 'area[3]'),
#  ('pmax[4]', 'area[4]'),
#  ('pmax[5]', 'negpmax[5]'),
#  ('pmax[5]', 'area[5]'),
#  ('negpmax[5]', 'area[5]'),
#  ('pmax[6]', 'area[6]'),
#  ('pmax[8]', 'area[8]'),
#  ('pmax[9]', 'area[9]'),
#  ('pmax[10]', 'area[10]'),
#  ('pmax[11]', 'area[11]'),
#  ('pmax[13]', 'area[13]'),
#  ('pmax[14]', 'area[14]'),
#  ('tmax[15]', 'tmax[16]'),
#  ('tmax[15]', 'tmax[17]'),
#  ('tmax[16]', 'tmax[17]')]

# %% [markdown]
# We will handle highly correlated features later with PCA

# %% [markdown]
# ## Outliers
# We have a multivariate problem, so We will detect outliers using Isolation Forest.
# We considered the following documentation, for choosing the outlier detector: https://scikit-learn.org/stable/modules/outlier_detection.html#overview-of-outlier-detection-methods

# %%
isolation_forest = IsolationForest(n_estimators=1000)
X_train['is_outlier'] = isolation_forest.fit_predict(X_train) # fit_predict returns -1 for outliers and 1 for inliers

# %%
X_train['is_outlier'].value_counts() 
# 2029 n_estimators=100
# 2809 n_estimators=1000
# 2544 n_estimators=10000
# Out:
#  1    267611
# -1      2239
# Name: is_outlier, dtype: int64

# %%
mask_is_outlier = X_train['is_outlier'] == -1
plt.scatter(y_train.x[~mask_is_outlier], y_train.y[~mask_is_outlier], c='orange', label='inliers')
plt.scatter(y_train.x[mask_is_outlier], y_train.y[mask_is_outlier], c='red', label='outliers', alpha=0.3)

plt.show()

# %%
X_train_without_outliers, y_train_without_outliers = X_train[~mask_is_outlier], y_train[~mask_is_outlier]
del(X_train_without_outliers['is_outlier'])
del(X_train['is_outlier'])

# %%
# Let's reset the index
X_train_without_outliers.reset_index(drop=True, inplace=True)
y_train_without_outliers.reset_index(drop=True, inplace=True)

# %% [markdown]
# # Normalization

# %%
scaler_without_outliers = StandardScaler()
scaler = StandardScaler()

X_train_without_outliers_scaled = scaler_without_outliers.fit_transform(X_train_without_outliers)
X_train_scaled = scaler.fit_transform(X_train)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_train_without_outliers_scaled = pd.DataFrame(X_train_without_outliers_scaled, columns=X_train.columns)

# %% [markdown]
# # PCA

# %%
pca = PCA()
pca_without_outliers = PCA()

pca.fit(X_train_scaled)
pca_without_outliers.fit(X_train_without_outliers_scaled)

plt.figure(figsize=(20,8))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.plot(np.cumsum(pca_without_outliers.explained_variance_ratio_))
# plt.xticks(ticks=np.arange(pca.n_features_), 
#             labels=[f'PC{i + 1}' for i in range(pca.n_features_)])


# plt.figure(figsize=(20,8))
# plt.plot(np.cumsum(pca.explained_variance_ratio_))
# plt.title('Xworkdf')
# #plt.ylim([0, 1.1])
# plt.xticks(ticks=np.arange(pca.n_features_), 
#            labels=[f'PC{i + 1}' for i in range(pca.n_features_)])
# plt.xlabel('Principal components')
# plt.ylabel('Cumulative explained variance')
# plt.grid()
# plt.show()

# %%
print(np.cumsum(pca.explained_variance_ratio_))
print(np.cumsum(pca_without_outliers.explained_variance_ratio_))
# Out:
# [0.09265431 0.17189915 0.20840624 0.24277017 0.2701079  0.29147687
#  0.3092045  0.32536225 0.34117631 0.35649147 0.37024946 0.38317385
#  0.39580491 0.40830884 0.42069668 0.4328985  0.44492961 0.45683976
#  0.46850847 0.48003572 0.49155268 0.50293178 0.51427085 0.52551907
#  0.53672811 0.54790585 0.5590589  0.57019881 0.58132065 0.59241924
#  0.60350962 0.61456927 0.62561931 0.63665448 0.64766916 0.65867167
#  0.66965836 0.68061588 0.69155481 0.70244595 0.71330107 0.72406319
#  0.73478183 0.74538089 0.75589097 0.76629629 0.7766554  0.78698371
#  0.7972071  0.80739681 0.81748269 0.82752806 0.83749376 0.84740841
#  0.85724503 0.86700581 0.87673854 0.88630605 0.89578127 0.90518669
#  0.91444404 0.92346204 0.93225638 0.94079499 0.94894872 0.95675644
#  0.96336263 0.96959502 0.97542439 0.98011166 0.98459657 0.98807887
#  0.9908995  0.99244697 0.99385347 0.99501665 0.99577816 0.99639204
#  0.99697366 0.99746321 0.99792591 0.99827968 0.99858783 0.99886432
#  0.99911558 0.99936265 0.99958155 0.99977892 0.99997332 1.        ]
# [0.09271196 0.17200469 0.20842205 0.2428436  0.27009839 0.291413
#  0.30911647 0.32525941 0.34103226 0.356334   0.36929071 0.38200345
#  0.39453358 0.40696023 0.41919808 0.43136458 0.44334307 0.45519147
#  0.46687108 0.4784128  0.48982983 0.50116847 0.51245842 0.52372305
#  0.53496298 0.54615766 0.55733017 0.56849095 0.57962392 0.59073525
#  0.60183389 0.61291737 0.62399899 0.63507118 0.64611394 0.65713542
#  0.66814694 0.67915185 0.69012667 0.70105558 0.71193664 0.72275057
#  0.733508   0.74412019 0.75470511 0.76523064 0.77564738 0.78600102
#  0.7963103  0.80654059 0.81671415 0.82681296 0.83686804 0.84681525
#  0.85672639 0.86657942 0.87635089 0.88598345 0.89555785 0.90505336
#  0.91436281 0.92338428 0.93223612 0.94077955 0.9489012  0.95670811
#  0.96331491 0.96954326 0.97537229 0.98007607 0.98456429 0.98804834
#  0.99089795 0.99244935 0.99385739 0.99502497 0.99578909 0.99640662
#  0.99699101 0.99748255 0.99792919 0.99828414 0.9985917  0.99886853
#  0.99912026 0.9993674  0.99958631 0.99978163 0.99997332 1.        ]

# %%
def findm(pca):
        m=0
        for i,var in enumerate(np.cumsum(pca.explained_variance_ratio_)):
                if var>=0.99:        
                        m=i+1 #It is +1 because the counting starts from 0
                        break    
        return m

# %%
n = findm(pca)
n_without_outliers = findm(pca_without_outliers)
n
print(f"n = {n} and n_without_outliers = {n_without_outliers}")
# Out:
# n = 73 and n_without_outliers = 73

# %%
pca = PCA(n_components=n)
pca_without_outliers = PCA(n_components=n_without_outliers)

pca.fit(X_train_scaled)
pca_without_outliers.fit(X_train_without_outliers_scaled)
# Out:
# PCA(n_components=73)

# %%
X_train_pca = pca.transform(X_train_scaled)
X_train_without_outliers_pca = pca_without_outliers.transform(X_train_without_outliers_scaled)

# %%
X_train_pca = pd.DataFrame(X_train_pca, columns=[f'PC{i + 1}' for i in range(n)])
X_train_without_outliers_pca = pd.DataFrame(X_train_without_outliers_pca, columns=[f'PC{i + 1}' for i in range(n_without_outliers)])

# %%
# Download the datasets with outliers and without outliers respectively
pd.concat([X_train, y_train], axis=1).to_csv(path + 'train.csv', index=False)
pd.concat([X_train_without_outliers, y_train_without_outliers], axis=1).to_csv(path + 'train_without_outliers.csv', index=False)

# Download the datasets scaled with outliers and without outliers respectively
pd.concat([X_train_scaled, y_train], axis=1).to_csv(path + 'train_scaled.csv', index=False)
pd.concat([X_train_without_outliers_scaled, y_train_without_outliers], axis=1).to_csv(path + 'train_without_outliers_scaled.csv', index=False)

# Download the datasets scaled and pca with outliers and without outliers respectively
pd.concat([X_train_pca, y_train], axis=1).to_csv(path + 'train_pca.csv', index=False)
pd.concat([X_train_without_outliers_pca, y_train_without_outliers], axis=1).to_csv(path + 'train_without_outliers_pca.csv', index=False)

# %%
# Download the test set
pd.concat([X_test, y_test], axis=1).to_csv(path + 'test.csv', index=False)

# %%
X_test = pd.read_csv(path + 'evaluation.csv', index_col=0)

# %%
X_test.head()
# Out:
#      pmax[0]  negpmax[0]   area[0]     tmax[0]    rms[0]    pmax[1]  \
# Id
# 0   4.400616   -4.257770  2.860212  176.600000  1.562814   8.738040
# 1   5.599571   -2.974570  9.400537   90.677386  1.129626  23.460358
# 2   3.731995   -5.662292  1.930957  155.200000  0.921757   4.837952
# 3   5.657729   -4.600342  5.593030   30.463179  1.269390  87.293692
# 4   3.716666   -4.583796  1.946927   33.600000  1.082743   9.593125
#
#     negpmax[1]    area[1]    tmax[1]    rms[1]  ...    pmax[16]  negpmax[16]  \
# Id                                              ...
# 0    -3.598874   5.554105  70.800000  0.729175  ...  614.621212   -42.232574
# 1   -20.616669  17.998419  72.800000  1.258335  ...  520.333440   -36.986118
# 2    -7.224267   3.289124  67.057395  0.793541  ...  607.642389   -46.680069
# 3   -45.786813  38.422989  71.800000  0.733773  ...  596.094911   -48.241263
# 4    -5.374179   7.767408  72.414459  1.572473  ...  620.793628   -37.618567
#
#       area[16]   tmax[16]   rms[16]    pmax[17]  negpmax[17]    area[17]  \
# Id
# 0   583.237137  70.693530  0.861022  608.931417   -42.728827  568.019556
# 1   550.540448  72.781390  0.259205  613.671695   -44.449564  586.292097
# 2   582.825835  71.407320  0.552691  608.996069   -45.877765  589.520958
# 3   577.835129  72.011986  0.361220  612.500144   -49.572583  583.795426
# 4   599.834735  72.251813  0.390639  621.557649   -45.189832  600.988676
#
#      tmax[17]   rms[17]
# Id
# 0   70.755552  0.328075
# 1   72.900695  0.401326
# 2   71.406020  0.343592
# 3   72.066338  0.429650
# 4   72.151243  0.358549
#
# [5 rows x 90 columns]

# %%
X_test_scaled = scaler_without_outliers.transform(X_test)

# %%
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
X_test_scaled.head()
# Out:
#     pmax[0]  negpmax[0]   area[0]   tmax[0]    rms[0]   pmax[1]  negpmax[1]  \
# 0 -0.316532    0.059665 -0.421775  1.328843  0.653849 -0.463328    0.157041
# 1  0.497444    0.175226  1.450808 -0.117491 -0.615426  0.416961   -0.325313
# 2 -0.770463   -0.066822 -0.687833  0.968617 -1.224501 -0.696525    0.054283
# 3  0.536929    0.028814  0.360668 -1.131076 -0.205907  4.233738   -1.038738
# 4 -0.780870    0.030304 -0.683260 -1.078274 -0.752797 -0.412200    0.106722
#
#     area[1]   tmax[1]    rms[1]  ...  pmax[16]  negpmax[16]  area[16]  \
# 0 -0.586467 -0.217572 -1.787058  ...  0.436753    -0.022144 -0.050865
# 1  0.892171 -0.150770 -0.229731  ... -6.455890     1.640702 -4.967441
# 2 -0.855593 -0.342578 -1.597629  ... -0.073414    -1.431763 -0.112713
# 3  3.319025 -0.184171 -1.773527  ... -0.917560    -1.926578 -0.863161
# 4 -0.323481 -0.163648  0.694785  ...  0.887970     1.440250  2.444902
#
#    tmax[16]   rms[16]  pmax[17]  negpmax[17]  area[17]  tmax[17]   rms[17]
# 0 -1.620812  1.359924 -0.008763     1.203690 -2.151972 -1.607005 -0.568859
# 1  1.997425 -0.649341  0.332447     0.709447  0.460931  2.060626  0.406211
# 2 -0.383823  0.330512 -0.004109     0.299228  0.922646 -0.494875 -0.362311
# 3  0.664058 -0.308745  0.248117    -0.762027  0.103917  0.634094  0.783253
# 4  1.079675 -0.210524  0.900085     0.496821  2.562485  0.779259 -0.163210
#
# [5 rows x 90 columns]

# %%
X_test_pca = pca_without_outliers.transform(X_test_scaled)
X_test_pca = pd.DataFrame(X_test_pca, columns=[f'PC{i + 1}' for i in range(n_without_outliers)])

# %%
X_test_pca.head()
# Out:
#         PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0  1.629857 -0.745691  1.760555 -2.381622  1.343619  0.151411 -2.818666
# 1  1.517629  3.076274 -3.382225  2.852259 -0.278230 -0.402498 -0.135110
# 2 -3.724859 -2.209823 -1.496526 -0.859501 -0.697731  1.346715  1.902724
# 3  3.684086  3.711003 -3.588187  0.538536 -0.568730 -0.125194  0.917239
# 4 -0.211798 -1.554031  0.301309  1.873918  1.960946 -0.149730  0.647476
#
#         PC8       PC9      PC10  ...      PC64      PC65      PC66      PC67  \
# 0 -3.143796 -0.029928  0.914150  ...  1.259451 -0.704438 -0.412991  0.323946
# 1  1.953874 -1.507724  2.555049  ...  0.024746 -0.174890  0.547531  0.507553
# 2 -1.719991 -0.912431 -1.082931  ... -0.604790 -0.663376 -1.364325  1.485729
# 3 -0.513079 -0.493551 -0.369154  ... -0.460239  0.311280  0.298886 -1.269371
# 4  1.002695  0.409701 -0.574692  ... -0.654365 -0.667967 -0.411477 -0.611224
#
#        PC68      PC69      PC70      PC71      PC72      PC73
# 0 -0.323665 -0.378121 -0.288998  0.032386  0.752390 -0.044894
# 1  0.563004 -0.643301  0.490933 -0.288196 -1.761478 -0.329305
# 2 -0.519272 -1.692171 -0.097181 -0.024450  0.628946  0.878947
# 3 -0.682081  0.412727  1.698919 -1.183571  0.306913  0.033599
# 4 -0.185831  0.070558  0.361773  0.647691 -0.235543 -0.415743
#
# [5 rows x 73 columns]

# %%
X_test_pca.to_csv(path + 'evaluation_pca.csv', index=True)
